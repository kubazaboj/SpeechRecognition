# %%
from main import cm_disp

cm_disp.plot()
# Out:
# Processing example1.ogg...
# Processing example2.ogg...
# Processing example3.ogg...
# Processing example4.ogg...
# New Data Shape: (16, 13)
# New Label Shape: (16,)
